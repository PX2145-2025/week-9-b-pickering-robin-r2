# %% [markdown]
# <a href="https://colab.research.google.com/github/PX2145-2025/week-9-b-pickering-robin-r2/blob/main/Year_2_Week_9_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Exercise 1

# %%
def orbit_solve (r0, v0, tmax, N, method = 'euler'):
    # set-up the time-step using tmax and N:
    dt = tmax / N

    # set up an array for the output times (using tmax, time-step and N):
    t = np.linspace(0, tmax, N)

    # set up arrays for the positions and velocities (see below)
    r = np.zeros((N, 2))  # Positions (x, y)
    v = np.zeros((N, 2))  # Velocities (vx, vy)

    # include the initial conditions in the arrays

    # then do the integration for all the integration points
    for i in range (0, N):
        r[i+1] = r[i] + v[i] * dt
        v[i+1] = v[i] + a[i] * dt
    # output the solution (arrays for positions and velocities) versus time
    return t, r, v

# %%
# Exercise 2

# %%
# Exercise 3

# %%
def orbit_solve (r0, v0, tmax, N, method = 'euler'):
    # set-up the time-step using tmax and N:
    dt = tmax / N

    # set up an array for the output times (using tmax, time-step and N):
    t = np.linspace(0, tmax, N)

    # set up arrays for the positions and velocities (see below)
    r = np.zeros((N, 2))  # Positions (x, y)
    v = np.zeros((N, 2))  # Velocities (vx, vy)

    # include the initial conditions in the arrays

    # then do the integration for all the integration points
    for i in range (0, N):

    if method == 'euler':

        r[i+1] = r[i] + v[i] * dt
        v[i+1] = v[i] + a[i] * dt

    if method == 'euler_cromer':

        r[i+1] = r[i] + v[i + 1] * dt
        v[i+1] = v[i] + a[i] * dt

    if method == 'verlet':

        r[i+1] = r[i] + v[i] * dt
        v[i+1] = v[i] + a[i] * dt

        r[i+1] = r[i] + ( v[i + 1] * dt ) + 0.5 * a[i] * dt**2
        v[i+1] = v[i] + (0.5 * (a[i] + a[i + 1] ) * dt)

# output the solution (arrays for positions and velocities) versus time
return t, r, v
# Out:
#   File "/tmp/ipython-input-2269815544.py", line 17
#     if method == 'euler':
#     ^
# IndentationError: expected an indented block after 'for' statement on line 15
